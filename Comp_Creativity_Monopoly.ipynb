# %% [markdown]
# # Computational Creativity Seminar, LMU, WS 2021/22
#
# ## Project: Interdimensional Monopoly
#
# ### Creators: Laura Luckert & Shaoqiu Zhang
#
# Topic Description: Zwei oder mehr Spieler spielen das klassische Monopoly, aber nach jedem "über Los" ändert sich das Thema des Spiels. Aus dem klassischen Monopoly wird ein "Star Wars" Monopoly, ein "Herr der Ringe" Monopoly etc. Die Namen der Straßen und Aktionsfelder ändern sich nach dem aktuellen Thema. Die Aktionskarten, Felder und Namen müssen sinnvoll generiert werden. Programmier-Aufwand sollte sich nicht auf eine aufwändige GUI richten, sondern auf die sinnvolle Generation neuer Dimensionen.

# %% [markdown]
# #### Target:
# * Each new dimension is related to a popular Netflix movie / series
# * Within the dimension, places and actions are generated from places that exist in this movie/series and useful actions related to the respective movie/series
#
# #### Data Sources:
# * Kaggle series / movie dataset with user rankings: https://www.kaggle.com/chasewillden/netflix-shows
# * https://github.com/prosecconetwork/The-NOC-List/blob/master/NOC/DATA/Veale's%20NOC%20List/Veales%20place%20elements.xlsx
# * Wikipedia API via https://pypi.org/project/Wikipedia-API/0.3.5/
# * Regularization via https://hatebase.org and https://github.com/dariusk/wordfilter
#
# #### How To
#
# ##### Randomization
# * Random selection of topic: Movie or series from netflix dataset, we only consider titles with a rating > 90 to pick only the most popular shows
# * For each topic, we retrieve the Wikipedia article, if there is none, the topic is discarded
# * Filtration: if Wikipedia article is too short, the topic is discarded
#
# ##### Plagiarism
# * we use the regular Monopoly action cards in combination with the Wikipedia data for action card text generation
#
# ##### Generation
# For places:
# * NER of wikipedia text to extract persons and locations
#
# For actions:
# * KeywordToText Generation with action card input and frequently used terms in the Wikipedia article (considering NERs)
#
# ##### Filtration & Creation
# * Fitness: Find a fitness metric for the existing places and actions and compare the generated text against it
# * -> Self-evaluation of system -> keep only above a certain treshold, otherwise trigger re-generation
#
# #### Output Structure

# %%
"""
{
"topic": "Topic Name",

"places": {
    "general_places": [("Name of Place", 1000), ("Name of Place 2", 2000)],
    "train_stations": [("Place 1",3000), ("Place 2",3000), ("Place 3",3000), ("Place 4",3000)]
    "jail": "Name of Place",
    "free_parking": "Name of Place"
    },
    
"actions": {
    "neutral_action": ["Go three fields back", "..."],
    "reward_action": ["Generate rewarding action for the player", "..."],
    "penalty_action": ["Generate punishing action for the player", "..."]
    }
}
"""
# Out:
# '\n{\n"topic": "Topic Name",\n\n"places": {\n    "general_places": [("Name of Place", 1000), ("Name of Place 2", 2000)],\n    "train_stations": ["Place 1", "Place 2", "Place 3", "Place 4"]\n    "jail": "Name of Place",\n    "free_parking": "Name of Place"\n    },\n    \n"actions": {\n    "neutral_action": ["Go three fields back", "..."],\n    "reward_action": ["Generate rewarding action for the player", "..."],\n    "penalty_action": ["Generate punishing action for the player", "..."]\n    }\n}\n'

# %% [markdown]
# ### 1. Select Topic (Dimension) via Netflix Data

# %%
#!conda install -n comp_creativity pandas -y
import sys
#sys.path
import pandas as pd
import os

PATH = "~/Desktop/"
FILENAME = "netflix_data.csv"

full_path = os.path.expanduser(PATH)
os.chdir(full_path)

netflix_data = pd.read_csv(FILENAME, sep=";")

# %%
netflix_data.head(10)
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA
# 7    The Vampire Diaries  TV-14
# 8       The Walking Dead  TV-MA
# 9    Pretty Little Liars  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
# 6  For mature audiences.  May not be suitable for...                110
# 7  Parents strongly cautioned. May be unsuitable ...                 90
# 8  For mature audiences.  May not be suitable for...                110
# 9  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80
# 5          2016               95.0                80
# 6          2013               97.0                80
# 7          2017               91.0                80
# 8          2015               98.0                80
# 9          2016               96.0                80

# %%
## select only shows with rating score > 90
netflix_subset = netflix_data[netflix_data["user rating score"] > 90]

# %%
## 271 titles remain
netflix_subset.shape[0]
# Out:
# 271

# %%
## randomly select topic
topic = netflix_subset.sample()["title"]
print(topic)
# Out:
# 61    The Vampire Diaries
# Name: title, dtype: object

# %% [markdown]
# ### 2. Get Data for Topic from Wikipedia API

# %% [markdown]
# https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/

# %%
import wikipediaapi

# %%
## for regular text output
wiki_en_wiki = wikipediaapi.Wikipedia(
        language='en',
        extract_format=wikipediaapi.ExtractFormat.WIKI)

## check if page for topic exists
if wiki_wiki.page(topic).exists():
    print("Topic is ok.")
    wiki_page = wiki_en.page(topic)
else:
    print("Find a new topic")
# Out:
# Topic is ok.

# %%
topic_text = wiki_page.text

# %% [markdown]
# ### 3. NER on Data to Identify Places
#
# Code from: https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da
# https://medium.com/spatial-data-science/how-to-extract-locations-from-text-with-natural-language-processing-9b77035b3ea4

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/lauraluckert/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/lauraluckert/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
## pos-tagging, maybe useful for actions?
topic_text_pos = preprocess(topic_text)

# %%
topic_text_pos
# Out:
# [('The', 'DT'),
#  ('Vampire', 'NNP'),
#  ('Diaries', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('American', 'JJ'),
#  ('supernatural', 'NN'),
#  ('teen', 'JJ'),
#  ('drama', 'NN'),
#  ('television', 'NN'),
#  ('series', 'NN'),
#  ('developed', 'VBN'),
#  ('by', 'IN'),
#  ('Kevin', 'NNP'),
#  ('Williamson', 'NNP'),
#  ('and', 'CC'),
#  ('Julie', 'NNP'),
#  ('Plec', 'NNP'),
#  (',', ','),
#  ('based', 'VBN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('book', 'NN'),
#  ('series', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('name', 'NN'),
#  ('written', 'VBN'),
#  ('by', 'IN'),
#  ('L.', 'NNP'),
#  ('J.', 'NNP'),
#  ('Smith', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('series', 'NN'),
#  ('premiered', 'VBD'),
#  ('on', 'IN'),
#  ('The', 'DT'),
#  ('CW', 'NNP'),
#  ('on', 'IN'),
#  ('September', 'NNP'),
#  ('10', 'CD'),
#  (',', ','),
#  ('2009', 'CD'),
#  (',', ','),
#  ('and', 'CC'),
#  ('concluded', 'VBD'),
#  ('on', 'IN'),
#  ('March', 'NNP'),
#  ('10', 'CD'),
#  (',', ','),
#  ('2017', 'CD'),
#  (',', ','),
#  ('having', 'VBG'),
#  ('aired', 'VBN'),
#  ('171', 'CD'),
#  ('episodes', 'NNS'),
#  ('over', 'IN'),
#  ('eight', 'CD'),
#  ('seasons', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('pilot', 'NN'),
#  ('episode', 'NN'),
#  ('attracted', 'VBD'),
#  ('the', 'DT'),
#  ('largest', 'JJS'),
#  ('audience', 'NN'),
#  ('for', 'IN'),
#  ('The', 'DT'),
#  ('CW', 'NNP'),
#  ('of', 'IN'),
#  ('any', 'DT'),
#  ('series', 'NN'),
#  ('premiere', 'NN'),
#  ('since', 'IN'),
#  ('the', 'DT'),
#  ('network', 'NN'),
#  ('began', 'VBD'),
#  ('in', 'IN'),
#  ('2006', 'CD'),
#  (';', ':'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('season', 'NN'),
#  ('averaged', 'VBD'),
#  ('3.60', 'CD'),
#  ('million', 'CD'),
#  ('viewers', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('most-watched', 'JJ'),
#  ('series', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('network', 'NN'),
#  ('before', 'IN'),
#  ('being', 'VBG'),
#  ('supplanted', 'VBN'),
#  ('by', 'IN'),
#  ('Arrow', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('show', 'NN'),
#  ('has', 'VBZ'),
#  ('received', 'VBN'),
#  ('numerous', 'JJ'),
#  ('award', 'NN'),
#  ('nominations', 'NNS'),
#  (',', ','),
#  ('winning', 'VBG'),
#  ('four', 'CD'),
#  ('People', 'NNPS'),
#  ("'s", 'POS'),
#  ('Choice', 'NNP'),
#  ('Award', 'NNP'),
#  ('and', 'CC'),
#  ('many', 'JJ'),
#  ('Teen', 'NNP'),
#  ('Choice', 'NNP'),
#  ('Awards', 'NNP'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('April', 'NNP'),
#  ('2015', 'CD'),
#  (',', ','),
#  ('lead', 'JJ'),
#  ('actress', 'NN'),
#  ('Nina', 'NNP'),
#  ('Dobrev', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('played', 'VBD'),
#  ('Elena', 'NNP'),
#  ('Gilbert', 'NNP'),
#  (',', ','),
#  ('confirmed', 'VBD'),
#  ('that', 'IN'),
#  ('she', 'PRP'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('leaving', 'VBG'),
#  ('the', 'DT'),
#  ('show', 'NN'),
#  ('after', 'IN'),
#  ('its', 'PRP$'),
#  ('sixth', 'JJ'),
#  ('season', 'NN'),
#  ('.', '.'),
#  ('Dobrev', 'NNP'),
#  ('returned', 'VBD'),
#  ('to', 'TO'),
#  ('record', 'VB'),
#  ('a', 'DT'),
#  ('voiceover', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('seventh-season', 'JJ'),
#  ('finale', 'NN'),
#  ('and', 'CC'),
#  ('returned', 'VBN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('guest', 'NN'),
#  ('star', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  ('finale', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('March', 'NNP'),
#  ('2016', 'CD'),
#  (',', ','),
#  ('The', 'DT'),
#  ('CW', 'NNP'),
#  ('renewed', 'VBD'),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  ('for', 'IN'),
#  ('an', 'DT'),
#  ('eighth', 'JJ'),
#  ('season', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('in', 'IN'),
#  ('July', 'NNP'),
#  ('of', 'IN'),
#  ('that', 'DT'),
#  ('year', 'NN'),
#  ('announced', 'VBD'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('eighth', 'JJ'),
#  ('season', 'NN'),
#  (',', ','),
#  ('consisting', 'VBG'),
#  ('of', 'IN'),
#  ('16', 'CD'),
#  ('episodes', 'NNS'),
#  (',', ','),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('the', 'DT'),
#  ('show', 'NN'),
#  ("'s", 'POS'),
#  ('last', 'JJ'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('final', 'JJ'),
#  ('season', 'NN'),
#  ('began', 'VBD'),
#  ('airing', 'VBG'),
#  ('on', 'IN'),
#  ('October', 'NNP'),
#  ('21', 'CD'),
#  (',', ','),
#  ('2016', 'CD'),
#  (',', ','),
#  ('and', 'CC'),
#  ('ended', 'VBD'),
#  ('March', 'NNP'),
#  ('10', 'CD'),
#  (',', ','),
#  ('2017', 'CD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('concepts', 'NNS'),
#  ('and', 'CC'),
#  ('characters', 'NNS'),
#  ('developed', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  ('served', 'VBD'),
#  ('to', 'TO'),
#  ('launch', 'VB'),
#  ('a', 'DT'),
#  ('media', 'NNS'),
#  ('franchise', 'NN'),
#  ('that', 'WDT'),
#  ('includes', 'VBZ'),
#  ('other', 'JJ'),
#  ('television', 'NN'),
#  ('series', 'NN'),
#  (',', ','),
#  ('web', 'JJ'),
#  ('series', 'NN'),
#  (',', ','),
#  ('novels', 'NNS'),
#  ('and', 'CC'),
#  ('comic', 'JJ'),
#  ('books', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('television', 'NN'),
#  ('series', 'NN'),
#  ('The', 'DT'),
#  ('Originals', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('also', 'RB'),
#  ('aired', 'VBD'),
#  ('on', 'IN'),
#  ('The', 'DT'),
#  ('CW', 'NNP'),
#  (',', ','),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('major', 'JJ'),
#  ('entry', 'NN'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('collection', 'NN'),
#  ('of', 'IN'),
#  ('connected', 'VBN'),
#  ('works', 'NNS'),
#  ('.', '.'),
#  ('Series', 'NNP'),
#  ('overview', 'IN'),
#  ('The', 'DT'),
#  ('series', 'NN'),
#  ('is', 'VBZ'),
#  ('set', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('fictional', 'JJ'),
#  ('town', 'NN'),
#  ('of', 'IN'),
#  ('Mystic', 'NNP'),
#  ('Falls', 'NNP'),
#  (',', ','),
#  ('Virginia', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('town', 'NN'),
#  ('charged', 'VBN'),
#  ('with', 'IN'),
#  ('supernatural', 'JJ'),
#  ('history', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('follows', 'VBZ'),
#  ('the', 'DT'),
#  ('life', 'NN'),
#  ('of', 'IN'),
#  ('Elena', 'NNP'),
#  ('Gilbert', 'NNP'),
#  ('(', '('),
#  ('Nina', 'NNP'),
#  ('Dobrev', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('a', 'DT'),
#  ('teenage', 'JJ'),
#  ('girl', 'NN'),
#  ('who', 'WP'),
#  ('has', 'VBZ'),
#  ('just', 'RB'),
#  ('lost', 'VBN'),
#  ('both', 'DT'),
#  ('parents', 'NNS'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('car', 'NN'),
#  ('accident', 'NN'),
#  (',', ','),
#  ('as', 'IN'),
#  ('she', 'PRP'),
#  ('falls', 'VBZ'),
#  ('in', 'IN'),
#  ('love', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('162-year-old', 'JJ'),
#  ('vampire', 'NN'),
#  ('named', 'VBN'),
#  ('Stefan', 'NNP'),
#  ('Salvatore', 'NNP'),
#  ('(', '('),
#  ('Paul', 'NNP'),
#  ('Wesley', 'NNP'),
#  (')', ')'),
#  ('.', '.'),
#  ('Their', 'PRP$'),
#  ('relationship', 'NN'),
#  ('becomes', 'VBZ'),
#  ('increasingly', 'RB'),
#  ('complicated', 'VBN'),
#  ('as', 'IN'),
#  ('Stefan', 'NNP'),
#  ("'s", 'POS'),
#  ('mysterious', 'JJ'),
#  ('older', 'JJR'),
#  ('brother', 'NN'),
#  ('Damon', 'NNP'),
#  ('Salvatore', 'NNP'),
#  ('(', '('),
#  ('Ian', 'NNP'),
#  ('Somerhalder', 'NNP'),
#  (')', ')'),
#  ('returns', 'NNS'),
#  (',', ','),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('plan', 'NN'),
#  ('to', 'TO'),
#  ('bring', 'VB'),
#  ('back', 'RP'),
#  ('their', 'PRP$'),
#  ('past', 'JJ'),
#  ('love', 'NN'),
#  ('Katherine', 'NNP'),
#  ('Pierce', 'NNP'),
#  ('(', '('),
#  ('also', 'RB'),
#  ('played', 'VBN'),
#  ('by', 'IN'),
#  ('Dobrev', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('a', 'DT'),
#  ('vampire', 'NN'),
#  ('who', 'WP'),
#  ('looks', 'VBZ'),
#  ('exactly', 'RB'),
#  ('like', 'JJ'),
#  ('Elena', 'NNP'),
#  ('.', '.'),
#  ('Although', 'IN'),
#  ('Damon', 'NNP'),
#  ('initially', 'RB'),
#  ('harbors', 'VBZ'),
#  ('a', 'DT'),
#  ('grudge', 'NN'),
#  ('against', 'IN'),
#  ('his', 'PRP$'),
#  ('brother', 'NN'),
#  ('for', 'IN'),
#  ('forcing', 'VBG'),
#  ('him', 'PRP'),
#  ('to', 'TO'),
#  ('become', 'VB'),
#  ('a', 'DT'),
#  ('vampire', 'NN'),
#  (',', ','),
#  ('he', 'PRP'),
#  ('later', 'RB'),
#  ('reconciles', 'VBZ'),
#  ('with', 'IN'),
#  ('Stefan', 'NNP'),
#  ('and', 'CC'),
#  ('falls', 'VBZ'),
#  ('in', 'IN'),
#  ('love', 'NN'),
#  ('with', 'IN'),
#  ('Elena', 'NNP'),
#  (',', ','),
#  ('creating', 'VBG'),
#  ('a', 'DT'),
#  ('love', 'NN'),
#  ('triangle', 'NN'),
#  ('among', 'IN'),
#  ('the', 'DT'),
#  ('three', 'CD'),
#  ('.', '.'),
#  ('Both', 'DT'),
#  ('brothers', 'NNS'),
#  ('attempt', 'VBP'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('Elena', 'NNP'),
#  ('as', 'IN'),
#  ('they', 'PRP'),
#  ('face', 'VBP'),
#  ('various', 'JJ'),
#  ('villains', 'NNS'),
#  ('and', 'CC'),
#  ('threats', 'NNS'),
#  ('to', 'TO'),
#  ('their', 'PRP$'),
#  ('town', 'NN'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('Katherine', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('brothers', 'NNS'),
#  ("'", 'POS'),
#  ('history', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('town', 'NN'),
#  ("'s", 'POS'),
#  ('mythology', 'NN'),
#  ('are', 'VBP'),
#  ('revealed', 'VBN'),
#  ('through', 'IN'),
#  ('flashbacks', 'NNS'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  ('goes', 'VBZ'),
#  ('on', 'IN'),
#  ('.', '.'),
#  ('Additional', 'NNP'),
#  ('storylines', 'NNS'),
#  ('revolve', 'VBP'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('other', 'JJ'),
#  ('inhabitants', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('town', 'NN'),
#  (',', ','),
#  ('most', 'RBS'),
#  ('notably', 'RB'),
#  ('Elena', 'NNP'),
#  ("'s", 'POS'),
#  ('younger', 'JJR'),
#  ('brother', 'NN'),
#  ('Jeremy', 'NNP'),
#  ('Gilbert', 'NNP'),
#  ('(', '('),
#  ('Steven', 'NNP'),
#  ('R.', 'NNP'),
#  ('McQueen', 'NNP'),
#  (')', ')'),
#  ('and', 'CC'),
#  ('aunt', '$'),
#  ('Jenna', 'NNP'),
#  ('Sommers', 'NNP'),
#  ('(', '('),
#  ('Sara', 'NNP'),
#  ('Canning', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('her', 'PRP$'),
#  ('best', 'JJS'),
#  ('friends', 'NNS'),
#  ('Bonnie', 'NNP'),
#  ('Bennett', 'NNP'),
#  ('(', '('),
#  ('Kat', 'NNP'),
#  ('Graham', 'NNP'),
#  (')', ')'),
#  ('and', 'CC'),
#  ('Caroline', 'NNP'),
#  ('Forbes', 'NNP'),
#  ('(', '('),
#  ('Candice', 'NNP'),
#  ('King', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('their', 'PRP$'),
#  ('mutual', 'JJ'),
#  ('friends', 'NNS'),
#  ('Matt', 'NNP'),
#  ('Donovan', 'NNP'),
#  ('(', '('),
#  ('Zach', 'NNP'),
#  ('Roerig', 'NNP'),
#  (')', ')'),
#  ('and', 'CC'),
#  ('Tyler', 'NNP'),
#  ('Lockwood', 'NNP'),
#  ('(', '('),
#  ('Michael', 'NNP'),
#  ('Trevino', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('Matt', 'NNP'),
#  ("'s", 'POS'),
#  ('older', 'JJR'),
#  ('sister', 'NN'),
#  ('Vicki', 'NNP'),
#  ('Donovan', 'NNP'),
#  ('(', '('),
#  ('Kayla', 'NNP'),
#  ('Ewell', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('and', 'CC'),
#  ('their', 'PRP$'),
#  ('history', 'NN'),
#  ('teacher', 'NN'),
#  (',', ','),
#  ('vampire', 'NN'),
#  ('hunter', 'NN'),
#  ('Alaric', 'NNP'),
#  ('Saltzman', 'NNP'),
#  ('(', '('),
#  ('Matthew', 'NNP'),
#  ('Davis', 'NNP'),
#  (')', ')'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('town', 'NN'),
#  ("'s", 'POS'),
#  ('politics', 'NNS'),
#  ('are', 'VBP'),
#  ('orchestrated', 'VBN'),
#  ('by', 'IN'),
#  ('descendants', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('original', 'JJ'),
#  ('founding', 'NN'),
#  ('families', 'NNS'),
#  (',', ','),
#  ('all', 'DT'),
#  ('comprising', 'VBG'),
#  ('a', 'DT'),
#  ('``', '``'),
#  ('Founders', 'NNP'),
#  ("'", 'POS'),
#  ('Council', 'NNP'),
#  ('.', '.'),
#  ("''", "''"),
#  ('They', 'PRP'),
#  ('guard', 'VBP'),
#  ('the', 'DT'),
#  ('town', 'NN'),
#  ('mainly', 'RB'),
#  ('from', 'IN'),
#  ('vampires', 'NNS'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('supernatural', 'JJ'),
#  ('threats', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('werewolves', 'NNS'),
#  (',', ','),
#  ('witches', 'NNS'),
#  (',', ','),
#  ('hybrids', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('ghosts', 'NNS'),
#  ('.', '.'),
#  ('Cast', 'NNP'),
#  ('and', 'CC'),
#  ('characters', 'NNS'),
#  ('Nina', 'NNP'),
#  ('Dobrev', 'NNP'),
#  ('as', 'IN'),
#  ('Elena', 'NNP'),
#  ('Gilbert', 'NNP'),
#  ('(', '('),
#  ('season', 'NN'),
#  ('1–6', 'CD'),
#  (';', ':'),
#  ('guest', 'JJS'),
#  ('season', 'NN'),
#  ('8', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('a', 'DT'),
#  ('young', 'JJ'),
#  ('orphan', 'NN'),
#  ('who', 'WP'),
#  ('falls', 'VBZ'),
#  ('in', 'IN'),
#  ('love', 'NN'),
#  ('with', 'IN'),
#  ('vampire', 'NN'),
#  ('Stefan', 'NNP'),
#  ('Salvatore', 'NNP'),
#  ('and', 'CC'),
#  ('later', 'RB'),
#  ('his', 'PRP$'),
#  ('brother', 'NN'),
#  (',', ','),
#  ('Damon', 'NNP'),
#  (',', ','),
#  ('creating', 'VBG'),
#  ('a', 'DT'),
#  ('love', 'NN'),
#  ('triangle', 'NN'),
#  ('.', '.'),
#  ('When', 'WRB'),
#  ('Stefan', 'NNP'),
#  ('shuts', 'VBZ'),
#  ('his', 'PRP$'),
#  ('humanity', 'NN'),
#  ('off', 'RB'),
#  ('after', 'IN'),
#  ('being', 'VBG'),
#  ('blackmailed', 'VBN'),
#  ('by', 'IN'),
#  ('Klaus', 'NNP'),
#  (',', ','),
#  ('Damon', 'NNP'),
#  ('is', 'VBZ'),
#  ('given', 'VBN'),
#  ('the', 'DT'),
#  ('opportunity', 'NN'),
#  ('to', 'TO'),
#  ('grow', 'VB'),
#  ('closer', 'JJR'),
#  ('to', 'TO'),
#  ('Elena', 'NNP'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('results', 'NNS'),
#  ('in', 'IN'),
#  ('her', 'PRP$'),
#  ('being', 'VBG'),
#  ('further', 'JJ'),
#  ('drawn', 'NN'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('supernatural', 'JJ'),
#  ('world', 'NN'),
#  ('and', 'CC'),
#  ('results', 'NNS'),
#  ('in', 'IN'),
#  ('her', 'PRP$'),
#  ('struggling', 'VBG'),
#  ('to', 'TO'),
#  ('survive', 'VB'),
#  ('supernatural', 'JJ'),
#  ('events', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('town', 'NN'),
#  ('.', '.'),
#  ('Dobrev', 'NNP'),
#  ('also', 'RB'),
#  ('portrays', 'VBZ'),
#  ('Elena', 'NNP'),
#  ("'s", 'POS'),
#  ('doppelgänger', 'NN'),
#  (',', ','),
#  ('Katerina', 'NNP'),
#  ('Petrova', 'NNP'),
#  ('also', 'RB'),
#  ('known', 'VBN'),
#  ('as', 'IN'),
#  ('Katherine', 'NNP'),
#  ('Pierce', 'NNP'),
#  ('.', '.'),
#  ('Dobrev', 'NNP'),
#  ('sporadically', 'RB'),
#  ('appeared', 'VBD'),
#  ('in', 'IN'),
#  ('subsequent', 'JJ'),
#  ('seasons', 'NNS'),
#  ('and', 'CC'),
#  ('played', 'VBD'),
#  ('a', 'DT'),
#  ('significant', 'JJ'),
#  ('role', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('fifth', 'NN'),
#  ('season', 'NN'),
#  ('.', '.'),
#  ('Dobrev', 'NNP'),
#  ('also', 'RB'),
#  ('plays', 'VBZ'),
#  ('the', 'DT'),
#  ('progenitor', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Petrova', 'NNP'),
#  ('doppelgängers', 'NNS'),
#  (',', ','),
#  ('Silas', 'NNP'),
#  ("'s", 'POS'),
#  ('true', 'JJ'),
#  ('love', 'NN'),
#  ('known', 'VBN'),
#  ('as', 'IN'),
#  ('Amara', 'NNP'),
#  (',', ','),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('fifth', 'NN'),
#  ('season', 'NN'),
#  (',', ','),
#  ('whom', 'WP'),
#  ('he', 'PRP'),
#  ('had', 'VBD'),
#  ('sought', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('afterlife', 'NN'),
#  ('for', 'IN'),
#  ('two', 'CD'),
#  ('thousand', 'CD'),
#  ('years', 'NNS'),
#  ('.', '.'),
#  ('Dobrev', 'NNP'),
#  ('also', 'RB'),
#  ('played', 'VBD'),
#  ('another', 'DT'),
#  ('doppelgänger', 'NN'),
#  ('Tatia', 'NNP'),
#  ('in', 'IN'),
#  ('The', 'DT'),
#  ('Originals', 'NNP'),
#  ('season', 'NN'),
#  ('2', 'CD'),
#  ('episode', 'NN'),
#  ('``', '``'),
#  ('Red', 'JJ'),
#  ('Door', 'NNP'),
#  ('.', '.'),
#  ("''", "''"),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('season', 'NN'),
#  ('6', 'CD'),
#  ('finale', 'NN'),
#  (',', ','),
#  ('Elena', 'NNP'),
#  ("'s", 'POS'),
#  ('life', 'NN'),
#  ('was', 'VBD'),
#  ('tied', 'VBN'),
#  ('to', 'TO'),
#  ('Bonnie', 'NNP'),
#  ("'s", 'POS'),
#  ('in', 'IN'),
#  ('such', 'JJ'),
#  ('a', 'DT'),
#  ('way', 'NN'),
#  ('that', 'IN'),
#  ('as', 'RB'),
#  ('long', 'RB'),
#  ('as', 'IN'),
#  ('Bonnie', 'NNP'),
#  ('is', 'VBZ'),
#  ('alive', 'JJ'),
#  (',', ','),
#  ('Elena', 'NNP'),
#  ('will', 'MD'),
#  ('remain', 'VB'),
#  ('asleep', 'JJ'),
#  ('.', '.'),
#  ('Damon', 'NNP'),
#  ('put', 'VBD'),
#  ('Elena', 'NNP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('coffin', 'NN'),
#  ('and', 'CC'),
#  ('had', 'VBD'),
#  ('her', 'PRP$'),
#  ('hidden', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('warehouse', 'NN'),
#  ('in', 'IN'),
#  ('Brooklyn', 'NNP'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('next', 'JJ'),
#  ('60', 'CD'),
#  ('years', 'NNS'),
#  ('or', 'CC'),
#  ('so', 'RB'),
#  ('while', 'IN'),
#  ('he', 'PRP'),
#  ('waits', 'VBZ'),
#  ('for', 'IN'),
#  ('her', 'PRP$'),
#  ('to', 'TO'),
#  ('wake', 'VB'),
#  ('up', 'RP'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  ('finale', 'NN'),
#  (',', ','),
#  ('Elena', 'NNP'),
#  ("'s", 'POS'),
#  ('curse', 'NN'),
#  ('is', 'VBZ'),
#  ('broken', 'VBN'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('reunites', 'VBZ'),
#  ('with', 'IN'),
#  ('Damon', 'NNP'),
#  ('and', 'CC'),
#  ('they', 'PRP'),
#  ('live', 'VBP'),
#  ('a', 'DT'),
#  ('long', 'JJ'),
#  ('and', 'CC'),
#  ('happy', 'JJ'),
#  ('life', 'NN'),
#  ('together', 'RB'),
#  ('with', 'IN'),
#  ('her', 'PRP$'),
#  ('becoming', 'VBG'),
#  ('a', 'DT'),
#  ('doctor', 'NN'),
#  ('.', '.'),
#  ('Paul', 'NNP'),
#  ('Wesley', 'NNP'),
#  ('as', 'IN'),
#  ('Stefan', 'NNP'),
#  ('Salvatore', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('good-hearted', 'JJ'),
#  ('and', 'CC'),
#  ('affectionate', 'JJ'),
#  ('vampire', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('complete', 'JJ'),
#  ('opposite', 'NN'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('older', 'NN'),
#  ('brother', 'NN'),
#  (',', ','),
#  ('Damon', 'NNP'),
#  ('Salvatore', 'NNP'),
#  ('.', '.'),
#  ('Later', 'NNP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  (',', ','),
#  ('Stefan', 'NNP'),
#  ('reverts', 'VBZ'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('old', 'JJ'),
#  ('ways', 'NNS'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('Ripper', 'NNP'),
#  ('to', 'TO'),
#  ('save', 'VB'),
#  ('Damon', 'NNP'),
#  ('from', 'IN'),
#  ('a', 'DT'),
#  ('werewolf', 'NN'),
#  ('bite', 'NN'),
#  ('.', '.'),
#  ('His', 'PRP$'),
#  ('role', 'NN'),
#  ('becomes', 'VBZ'),
#  ('more', 'RBR'),
#  ('antagonistic', 'JJ'),
#  (',', ','),
#  ('after', 'IN'),
#  ('being', 'VBG'),
#  ('forced', 'VBN'),
#  ('to', 'TO'),
#  ('turn', 'VB'),
#  ('his', 'PRP$'),
#  ('humanity', 'NN'),
#  ('off', 'RB'),
#  ('.', '.'),
#  ('Eventually', 'RB'),
#  (',', ','),
#  ('he', 'PRP'),
#  ('returns', 'VBZ'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('good-hearted', 'JJ'),
#  ('and', 'CC'),
#  ('caring', 'VBG'),
#  ('self', 'NN'),
#  ('and', 'CC'),
#  ('reconciles', 'NNS'),
#  ('with', 'IN'),
#  ('Elena', 'NNP'),
#  (',', ','),
#  ('but', 'CC'),
#  ('the', 'DT'),
#  ('relationship', 'NN'),
#  ('does', 'VBZ'),
#  ("n't", 'RB'),
#  ('last', 'JJ'),
#  ('long', 'RB'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('becomes', 'VBZ'),
#  ('human', 'JJ'),
#  ('again', 'RB'),
#  ('and', 'CC'),
#  ('marries', 'NNS'),
#  ('Caroline', 'NNP'),
#  ('in', 'IN'),
#  ('Season', 'NNP'),
#  ('8', 'CD'),
#  ('and', 'CC'),
#  ('is', 'VBZ'),
#  ('killed', 'VBN'),
#  ('afterwards', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  ('finale', 'NN'),
#  ('as', 'IN'),
#  ('he', 'PRP'),
#  ('sacrifices', 'VBZ'),
#  ('himself', 'PRP'),
#  ('to', 'TO'),
#  ('save', 'VB'),
#  ('Mystic', 'NNP'),
#  ('Falls', 'NNP'),
#  ('.', '.'),
#  ('Wesley', 'NNP'),
#  ('also', 'RB'),
#  ('portrays', 'VBZ'),
#  ('his', 'PRP$'),
#  ('revealed', 'JJ'),
#  ('doppelgänger', 'NN'),
#  (',', ','),
#  ('Silas', 'NNP'),
#  ('(', '('),
#  ('seasons', 'NNS'),
#  ('4–5', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ("'s", 'POS'),
#  ('first', 'JJ'),
#  ('immortal', 'JJ'),
#  ('being', 'VBG'),
#  ('.', '.'),
#  ('Wesley', 'NNP'),
#  ('also', 'RB'),
#  ...]

# %%
import spacy
from spacy import displacy
from collections import Counter
nlp = spacy.load('en_core_web_sm')

# %%
nlp_w = spacy.load('xx_ent_wiki_sm')

# %%
## roberta based
#nlp_b = spacy.load('en_core_web_trf')

# %%
doc = nlp(topic_text)
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('The Vampire Diaries', 'ORG'), ('American', 'NORP'), ('Kevin Williamson', 'PERSON'), ('Julie Plec', 'PERSON'), ('L. J. Smith', 'PERSON'), ('September 10, 2009', 'DATE'), ('March 10, 2017', 'DATE'), ('171', 'CARDINAL'), ('eight seasons', 'DATE'), ('2006', 'DATE'), ('the first season', 'DATE'), ('3.60 million', 'CARDINAL'), ('Arrow', 'ORG'), ('four', 'CARDINAL'), ('April 2015', 'DATE'), ('Nina Dobrev', 'PERSON'), ('Elena Gilbert', 'PERSON'), ('its sixth season', 'DATE'), ('Dobrev', 'ORG'), ('seventh-season', 'DATE'), ('March 2016', 'DATE'), ('CW', 'ORG'), ('an eighth season', 'DATE'), ('July of that year', 'DATE'), ('the eighth season', 'DATE'), ('16', 'CARDINAL'), ('The final season', 'DATE'), ('October 21, 2016', 'DATE'), ('March 10, 2017', 'DATE'), ('The Originals', 'WORK_OF_ART'), ('first', 'ORDINAL'), ('Mystic Falls', 'ORG'), ('Virginia', 'GPE'), ('162-year-old', 'DATE'), ('Stefan Salvatore', 'PERSON'), ('Paul Wesley', 'PERSON'), ('Stefan', 'PERSON'), ('Damon Salvatore', 'PERSON'), ('Ian Somerhalder', 'PERSON'), ('Katherine Pierce', 'PERSON'), ('Dobrev', 'ORG'), ('Elena', 'ORG'), ('Stefan', 'PERSON'), ('Elena', 'ORG'), ('three', 'CARDINAL'), ('Katherine', 'ORG'), ('Elena', 'ORG'), ('Jeremy Gilbert', 'PERSON'), ('Steven R. McQueen', 'PERSON'), ('Jenna Sommers', 'PERSON'), ('Sara Canning', 'PERSON'), ('Bonnie Bennett', 'PERSON'), ('Caroline Forbes', 'PERSON'), ('Candice King', 'PERSON'), ('Matt Donovan', 'PERSON'), ('Zach Roerig', 'PERSON'), ('Tyler Lockwood', 'PERSON'), ('Michael Trevino', 'PERSON'), ('Matt', 'PERSON'), ('Vicki Donovan', 'PERSON'), ('Ewell', 'PERSON'), ('Alaric Saltzman', 'PERSON'), ('Matthew Davis', 'PERSON'), ('season 1–6', 'DATE'), ('season 8)', 'DATE'), ('Stefan Salvatore', 'PERSON'), ('Stefan', 'PERSON'), ('Klaus', 'ORG'), ('Elena', 'ORG'), ('Dobrev', 'ORG'), ('Elena', 'ORG'), ('Katerina Petrova', 'PERSON'), ('Katherine Pierce', 'PERSON'), ('Dobrev', 'ORG'), ('the fifth season', 'DATE'), ('Dobrev', 'ORG'), ('Petrova', 'GPE'), ('Silas', 'ORG'), ('Amara', 'GPE'), ('the fifth season', 'DATE'), ('two thousand years', 'DATE'), ('Dobrev', 'ORG'), ('Tatia', 'PERSON'), ('Originals', 'ORG'), ('season 2', 'DATE'), ('Red Door', 'WORK_OF_ART'), ('Elena', 'ORG'), ('Bonnie', 'PERSON'), ('Bonnie', 'PERSON'), ('Damon put Elena', 'ORG'), ('Brooklyn', 'GPE'), ('the next 60 years', 'DATE'), ('Elena', 'ORG'), ('Paul Wesley', 'PERSON'), ('Stefan Salvatore', 'PERSON'), ('Damon Salvatore', 'PERSON'), ('Stefan', 'PERSON'), ('Ripper', 'PERSON'), ('Elena', 'ORG'), ('Caroline', 'ORG'), ('Season 8', 'DATE'), ('Mystic Falls', 'PERSON'), ('Wesley', 'PERSON'), ('first', 'ORDINAL'), ('Wesley', 'PERSON'), ('Tom Avery', 'PERSON'), ('the fifth season', 'DATE'), ('Ian Somerhalder', 'PERSON'), ('Damon Salvatore', 'PERSON'), ('Stefan', 'PERSON'), ('Elena', 'ORG'), ('one', 'CARDINAL'), ('Stefan', 'PERSON'), ('Ripper', 'PERSON'), ('season 4', 'DATE'), ('the end of season 6', 'DATE'), ('Stefan', 'PERSON'), ('Alaric', 'PERSON'), ('Bonnie', 'PERSON'), ('Steven R. McQueen', 'PERSON'), ('Jeremy Gilbert', 'PERSON'), ('seasons 1–6', 'DATE'), ('season 8)', 'DATE'), ('Elena', 'ORG'), ('Five', 'CARDINAL'), ('Jeremy', 'PERSON'), ('season 4', 'DATE'), ('Katherine', 'ORG'), ('Bonnie Bennett', 'PERSON'), ('season 4', 'DATE'), ('Sara Canning', 'PERSON'), ('Jenna Sommers', 'PERSON'), ('1–2', 'DATE'), ('3', 'CARDINAL'), ('5', 'DATE'), ('Jeremy', 'GPE'), ('season two', 'DATE'), ('Jenna', 'PERSON'), ('Klaus', 'ORG'), ('Kat Graham', 'PERSON'), ('Bonnie Bennett', 'PERSON'), ('Elena', 'ORG'), ('Caroline', 'ORG'), ('Sheila', 'PERSON'), ('Grams', 'WORK_OF_ART'), ('four months', 'DATE'), ('Bonnie', 'PERSON'), ('seasons 2', 'DATE'), ('5', 'CARDINAL'), ('Elena', 'ORG'), ('Jeremy', 'PERSON'), ('Enzo', 'PRODUCT'), ('season 7', 'DATE'), ('Bonnie', 'PERSON'), ("Rayna Cruz's", 'PERSON'), ('Candice King', 'PERSON'), ('Caroline Forbes', 'PERSON'), ('Elena', 'ORG'), ('Bonnie', 'PERSON'), ('first', 'ORDINAL'), ('the second season', 'DATE'), ('Caroline', 'ORG'), ('season 1', ' ...

# %%
entities = set()
for item in doc.ents:
    entities.add(item.label_)

print(entities)
# Out:
# {'ORDINAL', 'WORK_OF_ART', 'NORP', 'ORG', 'GPE', 'FAC', 'PRODUCT', 'PERSON', 'EVENT', 'DATE', 'CARDINAL', 'TIME'}

# %%
type(doc)
for item in doc.ents:
    if item.label_ == "GPE":
        print(item.text)
# Out:
# Virginia
# Petrova
# Amara
# Brooklyn
# Jeremy
# Tyler
# Alaric
# Vicki
# Jeremy
# Jenna
# Alaric
# Alaric
# Dallas
# New Orleans
# Vancouver
# British Columbia
# Covington
# Georgia
# Virginia
# Atlanta
# Covington
# United States
# the United Kingdom
# Brazil
# Australia
# the United Kingdom
# Brazil
# Japan
# New Orleans
# New Orleans
# New Orleans

# %%
doc_w = nlp_w(topic_text)

# %%
entities_w = set()
for item in doc_w.ents:
    entities_w.add(item.label_)

print(entities_w)
# Out:
# {'PER', 'MISC', 'LOC', 'ORG'}

# %%
for item in doc_w.ents:
    if item.label_ == "LOC":
        print(item.text)
# Out:
# Mystic Falls
# Virginia
# Brooklyn
# Ripper
# Silas
# Ripper
# Jeremy
# Mystic Falls
# Caroline
# Dallas
# New Orleans
# Vancouver
# British Columbia
# Covington
# Georgia
# Mystic Falls
# Virginia
# Greater Atlanta
# Clark Street
# Covington
# Trevino
# San Francisco Chronicle's Tim Goodman
# Meredith
# Region A
# B
# United Kingdom
# Brazil
# Australia
# B
# United Kingdom
# Brazil
# Japan
# Claire Holt
# Rebekah
# New Orleans
# New Orleans

# %% [markdown]
# ### 3. Text Generation via Keywords
# https://medium.com/mlearning-ai/generating-sentences-from-keywords-using-transformers-in-nlp-e89f4de5cf6b
