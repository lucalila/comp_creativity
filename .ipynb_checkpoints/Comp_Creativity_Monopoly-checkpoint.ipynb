# %% [markdown]
# # Computational Creativity Seminar, LMU, WS 2021/22
#
# ## Project: Interdimensional Monopoly
#
# ### Creators: Laura Luckert & Shaoqiu Zhang
#
# Topic Description: Zwei oder mehr Spieler spielen das klassische Monopoly, aber nach jedem "über Los" ändert sich das Thema des Spiels. Aus dem klassischen Monopoly wird ein "Star Wars" Monopoly, ein "Herr der Ringe" Monopoly etc. Die Namen der Straßen und Aktionsfelder ändern sich nach dem aktuellen Thema. Die Aktionskarten, Felder und Namen müssen sinnvoll generiert werden. Programmier-Aufwand sollte sich nicht auf eine aufwändige GUI richten, sondern auf die sinnvolle Generation neuer Dimensionen.

# %% [markdown]
# #### Target:
# * Each new dimension is related to a Netflix movie / series (random selection of series)
# * Within the dimension, places and actions are generated from places that exist in this movie/series and useful actions related to the respective movie/series
#
# #### Data Sources:
# * Random selection of series from this dataset from Kaggle: https://www.kaggle.com/chasewillden/netflix-shows
# we only consider titles with a rating > XX and number of ratings > YY to pick only the most popular, best ranked shows
# * For the selected show: Get information from Wikipedia API via https://pypi.org/project/Wikipedia-API/0.3.5/
# * Recommendation from Philipp Wicke: https://github.com/prosecconetwork/The-NOC-List/blob/master/NOC/DATA/Veale's%20NOC%20List/Veales%20place%20elements.xlsx
#
# #### How To
# * HOW DO WE DO THIS?
# * NER of wikipedia text? -> select places, rank places etc.
# * How to use Philipps Data?

# %%
#!conda install -n comp_creativity pandas -y
import sys
#sys.path
import pandas as pd
import os

PATH = "~/Desktop/"
FILENAME = "netflix_data.csv"

full_path = os.path.expanduser(PATH)
os.chdir(full_path)

netflix_data = pd.read_csv(FILENAME, sep=";")
# Out:
# /Users/lauraluckert/Desktop/

# %%
netflix_data.head(10)
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA
# 7    The Vampire Diaries  TV-14
# 8       The Walking Dead  TV-MA
# 9    Pretty Little Liars  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
# 6  For mature audiences.  May not be suitable for...                110
# ...

# %%
## select only shows with rating score > 90
netflix_subset = netflix_data[netflix_data["user rating score"] > 90]

# %%
## 271 titles remain
netflix_subset.shape[0]
# Out:
# 271

# %% [markdown]
# ### 2. Test Wikipedia API

# %% [markdown]
# https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/

# %%
# !conda install -n comp_creativity pip -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.1
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
# !conda update -n base -c defaults conda -y
# Out:
# ...
# Solving environment: -
# ...
#   - defaults/noarch::sphinx-2.4.0-py_0, defaults/osx-64::docutils-0.18.1-py37hecd8cb5_2
#   - defaults/noarch::sphinx-4.2.0-pyhd3eb1b0_1, defaults/osx-64::docutils-0.17.1-py37hecd8cb5done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-client-1.9.0      |   py37hecd8cb5_0         155 KB
#     anaconda-project-0.10.2    |     pyhd3eb1b0_0         218 KB
#     anyio-2.2.0                |   py37hecd8cb5_1         124 KB
#     appdirs-1.4.4              |     pyhd3eb1b0_0          12 KB
#     applaunchservices-0.2.1    |     pyhd3eb1b0_0           9 KB
#     appscript-1.1.2            |   py37h9ed2024_0         130 KB
#     argon2-cffi-20.1.0         |   py37h9ed2024_1          44 KB
# ...

# %%
# !conda update conda
# Out:
# ...
# Solving environment: /
# ...
#   - defaults/noarch::sphinx-2.4.0-py_0, defaults/osx-64::docutils-0.18.1-py37hecd8cb5_2
#   - defaults/noarch::sphinx-4.2.0-pyhd3eb1b0_1, defaults/osx-64::docutils-0.17.1-py37hecd8cb5done
#
# # All requested packages already installed.

# %%
# !source activate comp_creativity

# %%
# !conda info
# Out:
#      active environment : base
#     active env location : /opt/anaconda3
#             shell level : 1
#        user config file : /Users/lauraluckert/.condarc
#  populated config files : /Users/lauraluckert/.condarc
#           conda version : 4.11.0
#     conda-build version : 3.18.9
#          python version : 3.7.4.final.0
#        virtual packages : __osx=10.16=0
#                           __unix=0=0
#                           __archspec=1=x86_64
#        base environment : /opt/anaconda3  (writable)
#       conda av data dir : /opt/anaconda3/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /opt/anaconda3/pkgs
#                           /Users/lauraluckert/.conda/pkgs
# ...

# %%
import wikipediaapi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/jc/wfw7hm3d4_999_6bt6flqglw0000gn/T/ipykernel_791/2101694109.py in <module>
# ----> 1 import wikipediaapi
#
# ModuleNotFoundError: No module named 'wikipediaapi'

# %%
# !source deactivate

# %%
# !source activate comp_creativity

# %%
# !which pip
# Out:
# /opt/anaconda3/bin/pip
